# %%
# !pip install beir
# !pip install pandas
# !pip install sklearn
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip install ipywidgets
# Out:
# Requirement already satisfied: beir in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: datasets in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from beir) (2.12.0)
# Requirement already satisfied: elasticsearch==7.9.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from beir) (7.9.1)
# Requirement already satisfied: faiss_cpu in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from beir) (1.7.4)
# Requirement already satisfied: pytrec_eval in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from beir) (0.5)
# Requirement already satisfied: sentence-transformers in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from beir) (2.2.2)
# Requirement already satisfied: urllib3>=1.21.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from elasticsearch==7.9.1->beir) (2.0.2)
# Requirement already satisfied: certifi in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from elasticsearch==7.9.1->beir) (2023.5.7)
# Requirement already satisfied: numpy>=1.17 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (12.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (0.3.6)
# Requirement already satisfied: pandas in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (2.0.1)
# Requirement already satisfied: requests>=2.19.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (2.30.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (4.65.0)
# Requirement already satisfied: xxhash in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (3.2.0)
# Requirement already satisfied: multiprocess in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (2023.5.0)
# Requirement already satisfied: aiohttp in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (0.14.1)
# Requirement already satisfied: packaging in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (23.1)
# Requirement already satisfied: responses<0.19 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from datasets->beir) (6.0)
# Requirement already satisfied: nltk in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (3.8.1)
# Requirement already satisfied: scikit-learn in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (1.2.2)
# Requirement already satisfied: scipy in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (1.10.1)
# Requirement already satisfied: sentencepiece in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (0.1.99)
# Requirement already satisfied: torch>=1.6.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (2.0.1)
# Requirement already satisfied: torchvision in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (0.15.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sentence-transformers->beir) (4.28.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from aiohttp->datasets->beir) (1.3.1)
# Requirement already satisfied: filelock in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->beir) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->beir) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests>=2.19.0->datasets->beir) (3.4)
# Requirement already satisfied: sympy in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (1.11.1)
# Requirement already satisfied: networkx in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (3.1)
# Requirement already satisfied: jinja2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers->beir) (2.0.0)
# Requirement already satisfied: setuptools in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers->beir) (67.7.2)
# Requirement already satisfied: wheel in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers->beir) (0.40.0)
# Requirement already satisfied: cmake in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->beir) (3.26.3)
# Requirement already satisfied: lit in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->beir) (16.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->beir) (2023.5.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->beir) (0.13.3)
# Requirement already satisfied: click in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from nltk->sentence-transformers->beir) (8.1.3)
# Requirement already satisfied: joblib in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from nltk->sentence-transformers->beir) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas->datasets->beir) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas->datasets->beir) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas->datasets->beir) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from scikit-learn->sentence-transformers->beir) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from torchvision->sentence-transformers->beir) (9.5.0)
# Requirement already satisfied: six>=1.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->beir) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers->beir) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers->beir) (1.3.0)
# Requirement already satisfied: pandas in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: sklearn in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (0.0.post5)
# Requirement already satisfied: pip in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (23.1.2)
# Requirement already satisfied: setuptools in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (67.7.2)
# Requirement already satisfied: wheel in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (0.40.0)
# Requirement already satisfied: spacy in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (1.10.7)
# Requirement already satisfied: jinja2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jinja2->spacy) (2.1.2)
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: ipywidgets in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (8.0.6)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipywidgets) (6.23.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipywidgets) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipywidgets) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: comm>=0.1.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: psutil in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.1)
# Requirement already satisfied: backcall in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
from typing import Dict, List

from beir import util
from beir.datasets.data_loader import GenericDataLoader

import os
try:
    import ipywidgets
    from tqdm.auto import tqdm
except ModuleNotFoundError:
    from tqdm import tqdm

import spacy

import time
import numpy as np
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
import multiprocessing as mp

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/beir/util.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# # Available Datasets
#
# | Dataset   | Website| BEIR-Name | Domain     | Relevancy| Queries  | Documents | Avg. Docs/Q | Download |
# | -------- | -----| ---------| ----------- | ---------| ---------| --------- | ------| ------------|
# | MSMARCO    | [``Homepage``](https://microsoft.github.io/msmarco/)| ``msmarco`` | Misc.       |  Binary  |  6,980   |  8.84M     |    1.1 | Yes |
# | TREC-COVID |  [``Homepage``](https://ir.nist.gov/covidSubmit/index.html)| ``trec-covid``| Bio-Medical |  3-level|50|  171K| 493.5 | Yes |
# | NFCorpus   | [``Homepage``](https://www.cl.uni-heidelberg.de/statnlpgroup/nfcorpus/) | ``nfcorpus``  | Bio-Medical |  3-level |  323     |  3.6K     |  38.2 | Yes |
# | BioASQ     | [``Homepage``](http://bioasq.org) | ``bioasq``| Bio-Medical |  Binary  |   500    |  14.91M    |  8.05 | No |
# | NQ         | [``Homepage``](https://ai.google.com/research/NaturalQuestions) | ``nq``| Wikipedia   |  Binary  |  3,452   |  2.68M  |  1.2 | Yes |
# | HotpotQA   | [``Homepage``](https://hotpotqa.github.io) | ``hotpotqa``| Wikipedia   |  Binary  |  7,405   |  5.23M  |  2.0 | Yes |
# | FiQA-2018  | [``Homepage``](https://sites.google.com/view/fiqa/) | ``fiqa``    | Finance     |  Binary  |  648     |  57K    |  2.6 | Yes |
# | Signal-1M (RT) | [``Homepage``](https://research.signal-ai.com/datasets/signal1m-tweetir.html)| ``signal1m`` | Twitter     |  3-level  |   97   |  2.86M  |  19.6 | No |
# | TREC-NEWS  | [``Homepage``](https://trec.nist.gov/data/news2019.html) | ``trec-news``    | News     |  5-level  |   57    |  595K    |  19.6 | No |
# | ArguAna    | [``Homepage``](http://argumentation.bplaced.net/arguana/data) | ``arguana`` | Misc.       |  Binary  |  1,406     |  8.67K    |  1.0 | Yes |
# | Touche-2020| [``Homepage``](https://webis.de/events/touche-20/shared-task-1.html) | ``webis-touche2020``| Misc.       |  6-level  |  49     |  382K    |  49.2 |  Yes |
# | CQADupstack| [``Homepage``](http://nlp.cis.unimelb.edu.au/resources/cqadupstack/) | ``cqadupstack``| StackEx.      |  Binary  |  13,145 |  457K  |  1.4 |  Yes |
# | Quora| [``Homepage``](https://www.quora.com/q/quoradata/First-Quora-Dataset-Release-Question-Pairs) | ``quora``| Quora  | Binary  |  10,000     |  523K    |  1.6 |  Yes |
# | DBPedia | [``Homepage``](https://github.com/iai-group/DBpedia-Entity/) | ``dbpedia-entity``| Wikipedia |  3-level  |  400    |  4.63M    |  38.2 |  Yes |
# | SCIDOCS| [``Homepage``](https://allenai.org/data/scidocs) | ``scidocs``| Scientific |  Binary  |  1,000     |  25K    |  4.9 |  Yes |
# | FEVER| [``Homepage``](http://fever.ai) | ``fever``| Wikipedia     |  Binary  |  6,666     |  5.42M    |  1.2|  Yes |
# | Climate-FEVER| [``Homepage``](http://climatefever.ai) | ``climate-fever``| Wikipedia |  Binary  |  1,535     |  5.42M |  3.0 |  Yes |
# | SciFact| [``Homepage``](https://github.com/allenai/scifact) | ``scifact``| Scientific |  Binary  |  300     |  5K    |  1.1 |  Yes |

# %% [markdown]
# # Dataset Download & Pre-Processing

# %%
def download_dataset(dataset: str) -> Dict[str, List[str]]:
	'''
	PURPOSE: download the dataset
	ARGUMENTS:
		- dataset (str): string describing the beir dataset
	RETURN:
		- (List[str]) list of documents
	'''
	data_path = f'datasets/{dataset}'
	if not os.path.isdir(data_path):
		url = f'https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{dataset}.zip'
		out_dir = os.path.join(os.getcwd(), 'datasets')
		data_path = util.download_and_unzip(url, out_dir)
		print(f'Dataset downloaded here: {data_path}')
	corpus, _, _ = GenericDataLoader(data_path).load(split="test")
	return {doc_id: title_text['title'] + ' ' + title_text['text'] for doc_id, title_text in corpus.items()}

datasets = ['nfcorpus'] # Choosen datasets
threshold = 0.8

datasets_data = {dataset: download_dataset(dataset) for dataset in datasets}
# Out:
#   0%|          | 0/3633 [00:00<?, ?it/s]

# %% [markdown]
# ## Pre-Processing with Spacy

# %%
nlp = spacy.load('en_core_web_sm')
stopwords = nlp.Defaults.stop_words
clean_tokens = lambda tokens : ' '.join([token.lemma_.lower() for token in tokens if token not in stopwords and not token.is_punct])
# Lambda for text pre-processing

# %%
def pre_process(dictionary):
	'''
	PURPOSE: preprocess the text using spaCy
	ARGUMENTS:
		- corpus (str): string of document to pre-process
	RETURN:
		- str: cleaned document
	'''
	key, value = dictionary
	return {key: clean_tokens(nlp(value))}



def documents_preprocessing(dataset_name: str, documents: Dict[str, str]) -> Dict[str, str]:
	'''
	PURPOSE: preprocess all the documents and query for the relative dataset
	ARGUMENTS:
		- dataset_name (str): string describing the dataset name
		- documents (Dict[str, List[str]]): doc_id, document_text dictionary
	RETURN: 
		- new_documents (Dict[str, List[str]]): dictionary of cleaned documents
	'''
 
	path_datasets = os.path.join(os.getcwd(), 'datasets')
	if os.path.exists(os.path.join(path_datasets, dataset_name, 'pre_processed_corpus.parquet')):
		return pd.read_parquet(os.path.join(path_datasets, dataset_name, 'pre_processed_corpus.parquet')).to_dict()[0]
	
 
	new_documents = {}

	with ProcessPoolExecutor(max_workers=mp.cpu_count()) as executor:
		results = list(
				tqdm(
					executor.map(pre_process, documents.items()),
					total=len(documents),
					desc=f'{dataset_name} - Documents Pre-Processing',
				)
			)

	for result in results:
		new_documents |= result

	write_pd = pd.DataFrame.from_dict(new_documents, orient='index')
	write_pd.to_parquet(os.path.join(path_datasets, dataset_name, 'pre_processed_corpus.parquet'))

	return new_documents

# %%
# Dictionary of dataset: pre-processed documents
pre_processed_data = {dataset: documents_preprocessing(dataset, docs_dict) for dataset, docs_dict in datasets_data.items()}

# %% [markdown]
# # Sequential Version - All Pairs Documents Similarity

# %%
def classic_all_pairs_docs_sim(docs_list: List[str], threshold: float):
    count = 0
    doc_similaritis = []
    vectorizer = TfidfVectorizer()
    features = vectorizer.fit_transform(docs_list)
    
    
    start = time.time()
    similarities = cosine_similarity(features)
    for doc_1, doc_sims in enumerate(similarities):
        for doc_2, doc_sim in enumerate(doc_sims[(doc_1+1):], start=doc_1+1):
            if doc_sim >= threshold:
                count += 1
                doc_similaritis.append((doc_1, doc_2, doc_sim))
    end = time.time()
    
    
    return doc_similaritis, {'threshold': threshold, 'similar_doc': count, 'elapsed': end-start}

# %%
def npargwhere_all_pairs_docs_sim(docs_list: List[str], threshold: float):
    print()
    vectorizer = TfidfVectorizer()
    features = vectorizer.fit_transform(docs_list)
    
    
    start = time.time()
    similarities = cosine_similarity(features)
    np.fill_diagonal(similarities, 0.0)
    idx_doc_similaritis = np.argwhere(similarities > threshold)
    end = time.time()
    

    return [(similar.tolist(), similarities[similar[0], similar[1]]) for similar in idx_doc_similaritis], \
        {'threshold': threshold, 'similar_doc': int(len(idx_doc_similaritis)/2), 'elapsed': end-start}

# %%
def perform_all_pairs_docs_sim(data, threshold):
    result = {}
    for datasets_name, docs_list in data.items():
        print(f'All Documents Pairs Similarities - {datasets_name}')
        similar_list, stat = npargwhere_all_pairs_docs_sim(list(docs_list.values()), threshold)
        for tuple in similar_list: print(tuple)
        result[datasets_name] = stat
    return result

# %%
res = perform_all_pairs_docs_sim(pre_processed_data, threshold) 
res
# Out:
# All Documents Pairs Similarities - nfcorpus
#
# ([2, 1503], 1.0)
# ([4, 1675], 1.0000000000000002)
# ([8, 9], 0.8032354716247146)
# ([9, 8], 0.8032354716247146)
# ([10, 1844], 1.0000000000000002)
# ([27, 32], 1.0)
# ([32, 27], 1.0)
# ([54, 963], 1.0)
# ([272, 3090], 0.8403826284168192)
# ([376, 1120], 1.0000000000000002)
# ([930, 1376], 0.9999999999999999)
# ([963, 54], 1.0)
# ([1101, 2931], 1.0)
# ([1120, 376], 1.0000000000000002)
# ([1147, 3489], 1.0000000000000004)
# ([1162, 3235], 1.0000000000000004)
# ([1179, 1188], 1.0000000000000004)
# ([1188, 1179], 1.0000000000000004)
# ([1376, 930], 0.9999999999999999)
# ([1444, 2908], 1.0)
# ([1503, 2], 1.0)
# ([1591, 3599], 1.0000000000000004)
# ([1600, 1605], 0.8233866288823122)
# ([1605, 1600], 0.8233866288823122)
# ([1671, 1736], 1.0000000000000002)
# ([1672, 1742], 1.0)
# ([1674, 1739], 1.0)
# ([1675, 4], 1.0000000000000002)
# ([1678, 1729], 1.0000000000000002)
# ([1691, 2910], 1.0000000000000002)
# ([1695, 2972], 1.0000000000000002)
# ([1706, 3160], 1.0)
# ([1729, 1678], 1.0000000000000002)
# ([1736, 1671], 1.0000000000000002)
# ([1739, 1674], 1.0)
# ([1742, 1672], 1.0)
# ([1833, 2282], 1.0000000000000002)
# ([1844, 10], 1.0000000000000002)
# ([1851, 1861], 0.9999999999999999)
# ([1861, 1851], 0.9999999999999999)
# ([1894, 1902], 1.0000000000000002)
# ([1902, 1894], 1.0000000000000002)
# ([2014, 2730], 1.0000000000000004)
# ([2282, 1833], 1.0000000000000002)
# ([2303, 2749], 1.0000000000000002)
# ([2306, 3471], 0.9999999999999999)
# ([2314, 2317], 1.0000000000000002)
# ([2316, 2320], 1.0)
# ([2317, 2314], 1.0000000000000002)
# ([2320, 2316], 1.0)
# ([2346, 3154], 1.0)
# ([2354, 2355], 0.9978727360754368)
# ([2355, 2354], 0.9978727360754368)
# ([2366, 2370], 1.0)
# ([2370, 2366], 1.0)
# ([2599, 2971], 1.0)
# ([2623, 2909], 1.0)
# ([2628, 2907], 0.9999999999999998)
# ([2730, 2014], 1.0000000000000004)
# ([2749, 2303], 1.0000000000000002)
# ([2836, 2929], 1.0000000000000002)
# ([2895, 2959], 1.0000000000000002)
# ([2896, 2960], 1.0000000000000002)
# ([2899, 3545], 1.0000000000000002)
# ([2907, 2628], 0.9999999999999998)
# ([2908, 1444], 1.0)
# ([2909, 2623], 1.0)
# ([2910, 1691], 1.0000000000000002)
# ([2913, 3264], 1.0)
# ([2924, 3582], 1.0000000000000004)
# ([2929, 2836], 1.0000000000000002)
# ([2931, 1101], 1.0)
# ([2959, 2895], 1.0000000000000002)
# ([2960, 2896], 1.0000000000000002)
# ([2971, 2599], 1.0)
# ([2972, 1695], 1.0000000000000002)
# ([3090, 272], 0.8403826284168192)
# ([3154, 2346], 1.0)
# ([3160, 1706], 1.0)
# ([3235, 1162], 1.0000000000000004)
# ([3243, 3245], 1.0)
# ([3245, 3243], 1.0)
# ([3264, 2913], 1.0)
# ([3471, 2306], 0.9999999999999999)
# ([3489, 1147], 1.0000000000000004)
# ([3545, 2899], 1.0000000000000002)
# ([3582, 2924], 1.0000000000000004)
# ([3599, 1591], 1.0000000000000004)
# {'nfcorpus': {'threshold': 0.8,
#   'similar_doc': 44,
#   'elapsed': 1.1976044178009033}}

# %%
def perform_all_pairs_docs_sim(data, threshold):
    result = {}
    for datasets_name, docs_list in data.items():
        print(f'All Documents Pairs Similarities - {datasets_name}')
        similar_list, stat = classic_all_pairs_docs_sim(list(docs_list.values()), threshold)
        for tuple in similar_list: print(tuple)
        result[datasets_name] = stat
    return result

# %%
res = perform_all_pairs_docs_sim(pre_processed_data, threshold) 
res
# Out:
# All Documents Pairs Similarities - nfcorpus
# (2, 1503, 1.0)
# (4, 1675, 1.0000000000000002)
# (8, 9, 0.8032354716247146)
# (10, 1844, 1.0000000000000002)
# (27, 32, 1.0)
# (54, 963, 1.0)
# (272, 3090, 0.8403826284168192)
# (376, 1120, 1.0000000000000002)
# (930, 1376, 0.9999999999999999)
# (1101, 2931, 1.0)
# (1147, 3489, 1.0000000000000004)
# (1162, 3235, 1.0000000000000004)
# (1179, 1188, 1.0000000000000004)
# (1444, 2908, 1.0)
# (1591, 3599, 1.0000000000000004)
# (1600, 1605, 0.8233866288823122)
# (1671, 1736, 1.0000000000000002)
# (1672, 1742, 1.0)
# (1674, 1739, 1.0)
# (1678, 1729, 1.0000000000000002)
# (1691, 2910, 1.0000000000000002)
# (1695, 2972, 1.0000000000000002)
# (1706, 3160, 1.0)
# (1833, 2282, 1.0000000000000002)
# (1851, 1861, 0.9999999999999999)
# (1894, 1902, 1.0000000000000002)
# (2014, 2730, 1.0000000000000004)
# (2303, 2749, 1.0000000000000002)
# (2306, 3471, 0.9999999999999999)
# (2314, 2317, 1.0000000000000002)
# (2316, 2320, 1.0)
# (2346, 3154, 1.0)
# (2354, 2355, 0.9978727360754368)
# (2366, 2370, 1.0)
# (2599, 2971, 1.0)
# (2623, 2909, 1.0)
# (2628, 2907, 0.9999999999999998)
# (2836, 2929, 1.0000000000000002)
# (2895, 2959, 1.0000000000000002)
# (2896, 2960, 1.0000000000000002)
# (2899, 3545, 1.0000000000000002)
# (2913, 3264, 1.0)
# (2924, 3582, 1.0000000000000004)
# (3243, 3245, 1.0)
# {'nfcorpus': {'threshold': 0.8,
#   'similar_doc': 44,
#   'elapsed': 2.0110719203948975}}

# %% [markdown]
# # Parallel Version with Map Reduce from PySpark - All Pairs Documents Similarity

# %% [markdown]
# ## Download PySpark

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: py4j==0.10.9.7 in /home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# ## Active PySpark

# %%
from pyspark.sql import SparkSession

# Create SparkSession 
spark = SparkSession.builder \
    .master('local[1]') \
    .config("spark.driver.memory", "15g") \
    .appName("all_pairs_docs_similarity.com") \
    .getOrCreate()

sc = spark.sparkContext
# Out:
# 23/05/18 09:51:59 WARN Utils: Your hostname, riccardo-HP-EliteBook-840-G2 resolves to a loopback address: 127.0.1.1; using 192.168.1.5 instead (on interface wlo1)
# 23/05/18 09:51:59 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/18 09:52:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## PySpark Dataset Creation

# %%
# Create the features and columns vectors
vectorizer = TfidfVectorizer()
tfidf_features = vectorizer.fit_transform(pre_processed_data['nfcorpus'].values())
tfidf_columns = vectorizer.get_feature_names_out()

# %%
# Create a dictionary of key document ID and value the list of TF-IDF values
dict_pre_rrd = list(
    zip(pre_processed_data['nfcorpus'].keys(), tfidf_features.toarray())
)

l = [
	(1,  np.array([1,2,3,4,5,6,7])),
	(2, np.array([4,4,4,4,4,6,7])),
	(1, np.array([1,1,1,1,1,1,7])),
	(2, np.array([2,2,2,2,2,2,8]))
]

rdd = sc.parallelize(dict_pre_rrd) #tfidf_features.toarray()
#rdd.take(5)

# Get the d_star with the maximum TF-IDF value of each term from any documents
# todo

# %%
'''# Create the pandas Dataframe and convert it into a PySpark Dataframe
scifact_tfidf_pdf  = pd.DataFrame(data=tfidf_features.toarray(), index=pre_processed_data['scifact'].keys(), columns=tfidf_columns)
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled","true")
scifact_tfidf_df = spark.createDataFrame(scifact_tfidf_pdf)
scifact_rdd = scifact_tfidf_df.rdd # Obtain the rrd from the dataframe
print(scifact_rdd.take(5))

# Get the d_star with the maximum TF-IDF value of each term from any documents
d_star = scifact_tfidf_pdf.max(axis='rows')'''
# Out:
# '# Create the pandas Dataframe and convert it into a PySpark Dataframe\nscifact_tfidf_pdf  = pd.DataFrame(data=tfidf_features.toarray(), index=pre_processed_data[\'scifact\'].keys(), columns=tfidf_columns)\nspark.conf.set("spark.sql.execution.arrow.pyspark.enabled","true")\nscifact_tfidf_df = spark.createDataFrame(scifact_tfidf_pdf)\nscifact_rdd = scifact_tfidf_df.rdd # Obtain the rrd from the dataframe\nprint(scifact_rdd.take(5))\n\n# Get the d_star with the maximum TF-IDF value of each term from any documents\nd_star = scifact_tfidf_pdf.max(axis=\'rows\')'

# %%
def print_fun(x): print(x)

# %%
# Map function
def map_fun(pair):
    doc_id, tf_idf_list = pair
    return [(idx, (doc_id, tf_idf_list)) for idx in range(len(tf_idf_list))]

# %%
mapped = rdd.flatMap(map_fun)
mapped.collect()
# Out:
# 23/05/18 09:56:07 WARN TaskSetManager: Stage 9 contains a task of very large size (652925 KiB). The maximum recommended task size is 1000 KiB.
# ----------------------------------------ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
#
# Exception occurred during processing of request from ('127.0.0.1', 57862)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/accumulators.py", line 281, in handle
#     poll(accum_updates)
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/accumulators.py", line 253, in poll
#     if func():
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/accumulators.py", line 257, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/rdd.py:1814, in RDD.collect(self)
#    1813     assert self.ctx._jvm is not None
# -> 1814     sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#    1815 return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:169, in capture_sql_exception.<locals>.deco(*a, **kw)
#     168 try:
# --> 169     return f(*a, **kw)
#     170 except Py4JJavaError as e:
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#
# Py4JError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[16], line 2
#       1 mapped = rdd.flatMap(map_fun)
# ----> 2 mapped.collect()
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/rdd.py:1812, in RDD.collect(self)
#    1784 def collect(self: "RDD[T]") -> List[T]:
#    1785     """
#    1786     Return a list that contains all the elements in this RDD.
#    1787
#    (...)
#    1810     ['x', 'y', 'z']
#    1811     """
# -> 1812     with SCCallSiteSync(self.context):
#    1813         assert self.ctx._jvm is not None
#    1814         sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/pyspark/traceback_utils.py:81, in SCCallSiteSync.__exit__(self, type, value, tb)
#      79 SCCallSiteSync._spark_stack_depth -= 1
#      80 if SCCallSiteSync._spark_stack_depth == 0:
# ---> 81     self._context._jsc.setCallSite(None)
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/riccardo/Desktop/all-pairs-doc-sim/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving

# %%
rdd_temp = sc.parallelize([('0', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('1', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('2', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('3', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('4', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('5', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('6', ('ciao', np.array([1, 2, 3, 4, 5, 6, 7]))),
 ('0', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('1', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('2', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('3', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('4', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('5', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('6', ('ciao1', np.array([4, 4, 4, 4, 4, 6, 7]))),
 ('0', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('1', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('2', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('3', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('4', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('5', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('6', ('ciao2', np.array([1, 1, 1, 1, 1, 1, 7]))),
 ('0', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('1', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('2', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('3', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('4', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('5', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8]))),
 ('6', ('ciao3', np.array([2, 2, 2, 2, 2, 2, 8])))])#[("1", ('cacca', np.array([1,2,3,4,5]))), ("2", ('mucca', np.array([1,2,3,4,5]))), ("1", ('cucca', np.array([1,2,3,4,5])))])
#rdd_temp.collect()
rdd_temp1 = rdd_temp.groupByKey().mapValues(list)
rdd_temp1.collect()
# Out:
# [('0',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('1',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('2',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('3',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('4',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('5',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))]),
#  ('6',
#   [('ciao', array([1, 2, 3, 4, 5, 6, 7])),
#    ('ciao1', array([4, 4, 4, 4, 4, 6, 7])),
#    ('ciao2', array([1, 1, 1, 1, 1, 1, 7])),
#    ('ciao3', array([2, 2, 2, 2, 2, 2, 8]))])]

# %%
groupby = rdd.groupByKey().mapValues(list)
groupby.collect()
# Out:
# 23/05/18 09:55:11 WARN TaskSetManager: Stage 7 contains a task of very large size (652925 KiB). The maximum recommended task size is 1000 KiB.
# [('MED-1414', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4124', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1475', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1619', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1725', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2170', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2441', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2763', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3154', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3577',
#   [array([0.        , 0.08313524, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3943', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3953', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4305',
#   [array([0.        , 0.06335904, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4679', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4908', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5034', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5337', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2360', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2993', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4024', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1179', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1226', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1599', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1658', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1764', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1864',
#   [array([0.        , 0.06481902, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2225', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2977', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3227', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4069', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4329', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4437', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4606', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4785', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4950', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4981', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5173', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5237', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5353',
#   [array([0.        , 0.04135592, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3462', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4797', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2524', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2647', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1148', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1237', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1294', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1754', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1800', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2006', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2217', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2529',
#   [array([0.        , 0.04823386, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2804', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2982', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3302', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3615', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3642', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4116', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4250', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4320', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4438', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4722', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4938', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5286', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1487',
#   [array([0.        , 0.03551681, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2210', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2431', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2580', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2946', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4151', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-724', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1507', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1535', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1648', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2108', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2405', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2709', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2761', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2939', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2986', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3315', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3841', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3938', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4364', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4439',
#   [array([0.        , 0.04422067, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4543', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5212', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-937', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4509',
#   [array([0.05111636, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-118', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-732', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1037', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1315', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1459', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1610', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1696', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2453', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2488', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2703', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3378', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3540', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3937', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4491', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4613', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4820', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5084', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1018', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1072', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2361', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3770', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5150', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4609', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-911', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1015', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1448', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1624', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1841', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2327', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2504', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3589', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3696',
#   [array([0.05541069, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3811', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3842', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4005', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4090', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4632', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5204', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5215', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5350', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-836', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1114', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1349', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1861', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2371', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4787', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-728', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1638', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1944', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2019', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2057', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2153', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2340', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3085',
#   [array([0.02564193, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3312', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3896', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4481', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4501', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4666', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4853', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5221', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5256', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1322', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-888',
#   [array([0.        , 0.13314649, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1038', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1281', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1415', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1501', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2028', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2056', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2063', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2134', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2201', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2353', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2424', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3106', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3113', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3200',
#   [array([0.        , 0.04936206, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3484', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4071', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4112', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4182', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4415', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4485',
#   [array([0.04419724, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4658', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4669', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5002',
#   [array([0.05056999, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5029', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5111', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1351', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3380', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3816', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4691', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3237', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5127', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1291', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1499', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1569', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1607', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1748', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1757', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1836', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1979', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2036', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2509', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2571', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2655', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2791', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3437', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4131',
#   [array([0.        , 0.18558166, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4132',
#   [array([0.        , 0.03739137, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4225', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4924', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5171', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-948', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1426', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1674', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1737', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1917', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2034', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2330', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2475', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2570', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2664', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2811', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2851',
#   [array([0.0361442, 0.       , 0.       , ..., 0.       , 0.       ,
#           0.       ])]),
#  ('MED-3292', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3444', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3457', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3919', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4103', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4685',
#   [array([0.        , 0.08326535, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4759', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4867', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4902', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4917', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5042', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5290',
#   [array([0.        , 0.03310961, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1580', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1620', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2326', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2455', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3038', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3705', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4913', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5116', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-707', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1196', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1218', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1338',
#   [array([0.03875579, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1431', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1559', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1700', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2309', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2771', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3205', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4117', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4352', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4394', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4498', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4906', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4939', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4968', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5205', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1790', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2169', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3892', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5270', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-557', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1442', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1513', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2064', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2154', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2559', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3880',
#   [array([0.        , 0.13937562, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4080', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4342', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4619', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4676', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4920', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4990', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5064', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1358', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3109', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4089', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-885', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1679', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-818', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1362', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1412', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1420', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1718', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2059', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2111', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2218', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3646', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3972', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4255', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4389', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4426',
#   [array([0.        , 0.03101873, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4499', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4813', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4907', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4916', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5059', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5087', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5099', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5166', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5327', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1780', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2325', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4879', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4926', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4991', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-852', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1341', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1437', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2759', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3391',
#   [array([0.        , 0.03676536, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3542', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3543', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3788', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4513', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4627', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4649', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4869', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4896', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2148', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-831', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1111', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1167', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1280', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1493', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1551', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1814', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1837', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2213', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2414', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3059', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3595',
#   [array([0.05455951, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3624',
#   [array([0.        , 0.03142014, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3894', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3908', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4565', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4595', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4864', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4866', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5085', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5133', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1831', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3487', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3863', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1819', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3689', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4384', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1014', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1441', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1716', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2246', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2265', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2385', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2497', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2738', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3026', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3271', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3451', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3544', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3621', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3672', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3678', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3698', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4398',
#   [array([0.05438802, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4446', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4800', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4841', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5117', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1186', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1405', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1743', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1797', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5122', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5259', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-838', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-846',
#   [array([0.        , 0.03041167, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-958', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1418', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1947', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3274', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4430', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4454', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4696', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5044', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5194', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-718', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-731', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2297', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2369', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3141', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3182', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3373', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3427', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4767', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4901', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4494', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1736', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3232', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3744', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-966', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1133', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1598', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1807', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1867', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2079', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2521', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3055', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3137', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4162', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4233', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4424', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4464', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4702', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-873', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-985', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1172', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1309', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1429', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2033', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3966', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5197', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1004', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1013', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1530', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2001', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2087', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2226', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2231', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2389',
#   [array([0.04971761, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2669', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3310', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3374', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3557', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3720', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4380', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4782', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4824', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4884', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5266', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5316', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1730', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4220', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1107', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1250', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1630', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1852', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2706', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3179', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3513', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4193', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4456', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4846', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2046', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3173', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4410', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1436', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1827', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2667', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3493', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3637', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3707', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4436', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4556', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4741', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4840', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4862', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4972',
#   [array([0.        , 0.04906155, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5037', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5348', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1529', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2163', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4936', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5094', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5317', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1152',
#   [array([0.06178162, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1180', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1195', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1355', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1659', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1794', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2288', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2370', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2656', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2797', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3535', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3584', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3792', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3795', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3882', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3959', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3967', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4192', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4527', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4703', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4848', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5074', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5101', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5129', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5370', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1446', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1199',
#   [array([0.04223568, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1393', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1484', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1611', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1759', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1785', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2049', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2099', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2114', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2263', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2452', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2845',
#   [array([0.05631526, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2898', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3514', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3661', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3848', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3857', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3985', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4059', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4564', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-753', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1594', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2295',
#   [array([0.        , 0.03977116, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2507', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3399', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2653', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4524', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5049', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-979', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1366', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1515', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1587', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1622', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1957', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3724', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3906', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3947', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4379', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4719', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4914', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5214', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-938', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-823', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3606', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4486', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5361',
#   [array([0.        , 0.04535684, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1023', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1401', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1455', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1926', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2209', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2448', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3028',
#   [array([0.05681222, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3488', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3552', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3644', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3983', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4593', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5030', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5077', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5177', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1865', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1194', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1236', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1689', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1791', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1983', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2702', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2967', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3655', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4659', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2750',
#   [array([0.04847856, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2853', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3591', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4094', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5095',
#   [array([0.       , 0.0582753, 0.       , ..., 0.       , 0.       ,
#           0.       ])]),
#  ('MED-1165', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4825',
#   [array([0.        , 0.07253333, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-14',
#   [array([0.04757895, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-819', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1005',
#   [array([0.04556417, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1157', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1219', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1496', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1693', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1715', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1966', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4451', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4663', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5063', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1359', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1479', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1876', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2700', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3460', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-991', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1328', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1456', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1606', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1656', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1786', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1961', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2280', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2807', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2809', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3142', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3563', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3893', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3927', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3945', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4115', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4378', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4510', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4604', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5012', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5369', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-933', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1070', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3970',
#   [array([0.        , 0.06952883, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4447', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1387',
#   [array([0.04337366, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-956', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1151', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1223', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1820', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2124', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2141', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2618', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2925', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3210', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3421', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4300', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4975', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5234', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5238', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5297', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5325', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4051', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4337', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4756', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2032', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3784', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5190', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2161', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2200', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2245', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2386', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2812', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3095', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3359', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3530', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3536', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4032', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4138', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4246', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5263', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5288', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-730', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3199', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1188',
#   [array([0.        , 0.05695195, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1775', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1985', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2009', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2461', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2708', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2714', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2824', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3027', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3044', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3235', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3442', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3496', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3582', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3961', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4070', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4157', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4278', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4333', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4411', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4817', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4946', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5008', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1320', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1849', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2357', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2697', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3001', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3434', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3447', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3501', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4166', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4354', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4393', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4504', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4554', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4706', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5053',
#   [array([0.05823544, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5108', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-874', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2594', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2830', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1963', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2577', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1407', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1505', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1636', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2264', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2368', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2810', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3459', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3558', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3973', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4172', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4452', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4672', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4937', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5239', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5332', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5343', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1381', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2765', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3603', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3940', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-708', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-851', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1298', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2093', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2105', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2128', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2136', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2527', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2741', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3769', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3818', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3850', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4308', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4525', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4739', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4760', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5303', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2270', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2409', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3742', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-884', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1016', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1099', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1324', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1643', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2269', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2298', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2502', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2673', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2762', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3090', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4211', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4403', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4551', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4629', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4752', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4806', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5292', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1347', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1465', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2095', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2518', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3518', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3673', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3990',
#   [array([0.03299343, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1333', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1400', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1613', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1641', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2003', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2258',
#   [array([0.        , 0.10179331, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2282', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2332', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2757',
#   [array([0.04521896, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2790', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3797', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3806',
#   [array([0.05442957, 0.04979483, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-3808', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4148', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4345', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4355', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4413', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4600', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4721', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4842', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5278', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5347', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-934', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5213', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1585', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1825', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2492',
#   [array([0.        , 0.02576213, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-2572', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2672', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2885', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2985', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3153', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3250', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3604', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3743', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4068', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4159',
#   [array([0.        , 0.02104436, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4239', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4445', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4471', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4707', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4918', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5010', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5172', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4201', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-905', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1408', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-720', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-825', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-931', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1053', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1702', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2584', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2721', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2788', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3956', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3989', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4183', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4404', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4838', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4880', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5105', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5293', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2994', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3306',
#   [array([0.08811336, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4921', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1262', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-722', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1208', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1256', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1634', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1942', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2016', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2021', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2363', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3697', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4181', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4574', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4943', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5149', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5341',
#   [array([0.        , 0.04571715, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-719', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1030', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3143', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3748', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-986', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1531', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1811', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1838', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2501', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2891', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2988', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3135', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4299',
#   [array([0.        , 0.05407682, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4678',
#   [array([0.        , 0.03460308, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5130', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5152', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5160', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5362', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-862', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-876', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-946',
#   [array([0.06281432, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1071', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1233', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1284', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1390', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1540', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1747', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2177', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3087', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3506', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4626', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5169', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5200', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5352', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5367', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-691', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2078', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1425', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2261', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3356', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-894', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1136', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1247',
#   [array([0.        , 0.        , 0.        , ..., 0.        , 0.07660301,
#           0.        ])]),
#  ('MED-1274', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1279', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2041', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2053', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2582', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2884', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3231', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3355', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3395', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4303', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4816', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4843', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5057', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5175', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2451', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2792', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3029', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3422', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4206', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-940', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-867', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1171', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1843', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2183', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2429', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2589', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2751', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2910', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3164', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3221', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3766',
#   [array([0.       , 0.0483777, 0.       , ..., 0.       , 0.       ,
#           0.       ])]),
#  ('MED-3802', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3986',
#   [array([0.        , 0.07783111, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-4035', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4442', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4822', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4861',
#   [array([0.04216091, 0.03857086, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5091', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1578', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2204', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-714', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-843',
#   [array([0.        , 0.05486104, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-950',
#   [array([0.1579836, 0.       , 0.       , ..., 0.       , 0.       ,
#           0.       ])]),
#  ('MED-988', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1060', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1063',
#   [array([0.09279332, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1241', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1273', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1521', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1962', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2450', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2670', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2707', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2785', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3088', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3228', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3370', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3752', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5006', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5109',
#   [array([0.        , 0.04891914, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-5258', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3942', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4780',
#   [array([0.04309009, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-975', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1350', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3567', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5244', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1486', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1528', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1677', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1850', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2220', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3294', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3671', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4163', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4791', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4858', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-942', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1039', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1523', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1614', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2216', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2940', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4027', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-837', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1110', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1318', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1321', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1915', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2406', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2428', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2711', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2743', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2748', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2922', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3050', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3504', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3509', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-3856', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4154', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4237', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4377', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4594', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4875', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5247',
#   [array([0.04292519, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1026', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-4359', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-761', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1272',
#   [array([0.      , 0.046009, 0.      , ..., 0.      , 0.      , 0.      ])]),
#  ('MED-1449', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2055', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-2276', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ...]

# %%
# Reduce function
def reduce_fun(doc_id_doc_list):
    res = []
    for id1, d1 in doc_id_doc_list:
        res.extend(
            (id1, id2, cosine_similarity(d1, d2))
            for id2, d2 in doc_id_doc_list
            if cosine_similarity(d1, d2) >= threshold
        )
    return res

# %%
reduced = groupby.reduceByKey(reduce_fun)
reduced.take(5)
# Out:
# [('MED-861', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-1273', [array([0., 0., 0., ..., 0., 0., 0.])]),
#  ('MED-5109',
#   [array([0.        , 0.04891914, 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1063',
#   [array([0.09279332, 0.        , 0.        , ..., 0.        , 0.        ,
#           0.        ])]),
#  ('MED-1246', [array([0., 0., 0., ..., 0., 0., 0.])])]

# %%
#sc.stop()
